# %% [markdown]
# # Question 1
# ## Part 1

# %%
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from nltk import wordpunct_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
# %matplotlib inline

# %%
d = path.dirname('hillary-clinton-emails/')

# Read the whole text of the emails.
text = open(path.join(d, 'Emails.csv')).read()

# %%
# Generate and display wordcloud with a lower max_font_size
wordcloud = WordCloud(max_font_size=60).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Now if we take not the full data in *Emails.csv*, but only the *ExtractedBodyText*.

# %%
fullDF = pd.read_csv('hillary-clinton-emails/Emails.csv')
DFbody = fullDF.ExtractedBodyText.dropna()
print(DFbody.head(10))
# Out:
# 1     B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 2                                                   Thx
# 4     H <hrod17@clintonemail.com>\nFriday, March 11,...
# 5     Pis print.\n-•-...-^\nH < hrod17@clintonernail...
# 7     H <hrod17@clintonemail.corn>\nFriday, March 11...
# 8                                                   FYI
# 9     B6\nWednesday, September 12, 2012 6:16 PM\nFwd...
# 10                                         Fyi\nB6\n— —
# 11    B6\nWednesday, September 12, 2012 6:16 PM\nFwd...
# 12                                                  Fyi
# Name: ExtractedBodyText, dtype: object

# %%
fullDF['ExtractedBodyText'].to_csv('hillary-clinton-emails/BodyEmails.csv')

# %%
bodyCSV = open(path.join(d, 'BodyEmails.csv')).read()
bodyCSV[0:1000]
# Out:
# '0,\n1,"B6\nThursday, March 3, 2011 9:45 PM\nH: Latest How Syria is aiding Qaddafi and more... Sid\nhrc memo syria aiding libya 030311.docx; hrc memo syria aiding libya 030311.docx\nMarch 3, 2011\nFor: Hillary"\n2,Thx\n3,\n4,"H <hrod17@clintonemail.com>\nFriday, March 11, 2011 1:36 PM\nHuma Abedin\nFw: H: Latest: How Syria is aiding Qaddafi and more... Sid\nhrc memo syria aiding libya 030311.docx\nPis print."\n5,"Pis print.\n-•-...-^\nH < hrod17@clintonernailcom>\nWednesday, September 12, 2012 2:11 PM\n°Russorv@state.gov\'\nFw: Meet The Right-Wing Extremist Behind Anti-fvluslim Film That Sparked Deadly Riots\nFrom [meat)\nSent: Wednesday, September 12, 2012 01:00 PM\nTo: 11\nSubject: Meet The Right Wing Extremist Behind Anti-Muslim Film That Sparked Deadly Riots\nhtte/maxbiumenthal.com12012/09/meet-the-right-wing-extremist-behind-anti-musiim-tihn-that-sparked-\ndeadly-riots/\nSent from my Verizon Wireless 4G LTE DROID\nU.S. Department of State\nCase No. F-2015-04841\nDoc No. C05739559\nDate: 05/13/2015\nSTATE DEPT. - P'

# %%
# Display wordcloud with a lower max_font_size
wordcloud = WordCloud(max_font_size=60).generate(bodyCSV)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Part 2
# ### Tokenization

# %%
#tokens = nltk.word_tokenize(bodyCSV)
tokens = wordpunct_tokenize(bodyCSV) # Better to consider punctuation

# %%
print(tokens[0:30])
print(len(tokens))
# Out:
# ['0', ',', '1', ',"', 'B6', 'Thursday', ',', 'March', '3', ',', '2011', '9', ':', '45', 'PM', 'H', ':', 'Latest', 'How', 'Syria', 'is', 'aiding', 'Qaddafi', 'and', 'more', '...', 'Sid', 'hrc', 'memo', 'syria']
# 762245

# %% [markdown]
# ### Stop words

# %%
filtered_tokens = [word for word in tokens if word not in stopwords.words('english')]

# %%
print(filtered_tokens[0:30])
print(len(filtered_tokens))
# Out:
# ['0', ',', '1', ',"', 'B6', 'Thursday', ',', 'March', '3', ',', '2011', '9', ':', '45', 'PM', 'H', ':', 'Latest', 'How', 'Syria', 'aiding', 'Qaddafi', '...', 'Sid', 'hrc', 'memo', 'syria', 'aiding', 'libya', '030311']
# 530167

# %%
filteredBody = ' '.join(filtered_tokens)

# %%
# Display wordcloud with a lower max_font_size
wordcloud = WordCloud(max_font_size=60).generate(filteredBody)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Stemming
# * First way: LancasterStemmer

# %%
from nltk.stem.lancaster import LancasterStemmer

# %%
st = LancasterStemmer()
stemmed_tokens = [st.stem(word) for word in filtered_tokens]

# %%
print(stemmed_tokens[0:30])
print(len(stemmed_tokens))
# Out:
# ['0', ',', '1', ',"', 'b6', 'thursday', ',', 'march', '3', ',', '2011', '9', ':', '45', 'pm', 'h', ':', 'latest', 'how', 'syr', 'aid', 'qaddaf', '...', 'sid', 'hrc', 'memo', 'syr', 'aid', 'liby', '030311']
# 530167

# %%
stemmedBody = ' '.join(stemmed_tokens)

# %%
# Display wordcloud with a lower max_font_size
wordcloud = WordCloud(max_font_size=60).generate(stemmedBody)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# * Second way: WordNetLemmatizer

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
lm = WordNetLemmatizer()
stemmed_tokens2 = [lm.lemmatize(word.lower()) for word in filtered_tokens]

# %%
print(stemmed_tokens2[0:30])
print(len(stemmed_tokens2))
# Out:
# ['0', ',', '1', ',"', 'b6', 'thursday', ',', 'march', '3', ',', '2011', '9', ':', '45', 'pm', 'h', ':', 'latest', 'how', 'syria', 'aiding', 'qaddafi', '...', 'sid', 'hrc', 'memo', 'syria', 'aiding', 'libya', '030311']
# 530167

# %%
stemmedBody2 = ' '.join(stemmed_tokens2)

# %%
# Display wordcloud with a lower max_font_size
wordcloud = WordCloud(max_font_size=60).generate(stemmedBody2)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Question 2

# %%
import pycountry

# %%
emails = fullDF['ExtractedBodyText']
i = 0
occurencies = defaultdict(int)
for email_no_tokens in emails:
    if type(email_no_tokens) != float:
        email_no_lem = wordpunct_tokenize(email_no_tokens)
        lm = WordNetLemmatizer()
        email = [lm.lemmatize(word.lower()) for word in email_no_lem]
        for country in list(pycountry.countries):
            if type(country.name) != float:
                occurencies[country.name] += email.count(country.name) \
                    + email.count(lm.lemmatize(country.name.lower()))
                #if type(country.alpha_2) != float:
                #    occurencies[country.name] += email.count(country.alpha_2)
                #if type(country.alpha_3) != float:
                #    occurencies[country.name] += email.count(country.alpha_3)
    i = i+1
    if i%500 == 0:
        print(i, 'emails analysed.')
# Out:
# 500 emails analysed.
# 1000 emails analysed.
# 1500 emails analysed.
# 2000 emails analysed.
# 2500 emails analysed.
# 3000 emails analysed.
# 3500 emails analysed.
# 4000 emails analysed.
# 4500 emails analysed.
# 5000 emails analysed.
# 5500 emails analysed.
# 6000 emails analysed.
# 6500 emails analysed.
# 7000 emails analysed.
# 7500 emails analysed.

# %%
occurencies
# Out:
# defaultdict(int,
#             {'Afghanistan': 395,
#              'Albania': 2,
#              'Algeria': 3,
#              'American Samoa': 0,
#              'Andorra': 0,
#              'Angola': 10,
#              'Anguilla': 0,
#              'Antarctica': 1,
#              'Antigua and Barbuda': 0,
#              'Argentina': 21,
#              'Armenia': 8,
#              'Aruba': 0,
#              'Australia': 19,
#              'Austria': 7,
#              'Azerbaijan': 14,
#              'Bahamas': 1,
#              'Bahrain': 3,
#              'Bangladesh': 6,
#              'Barbados': 0,
#              'Belarus': 1,
#              'Belgium': 6,
#              'Belize': 0,
#              'Benin': 0,
#              'Bermuda': 3,
#              'Bhutan': 0,
#              'Bolivia, Plurinational State of': 0,
#              'Bonaire, Sint Eustatius and Saba': 0,
#              'Bosnia and Herzegovina': 0,
#              'Botswana': 0,
#              'Bouvet Island': 0,
#              'Brazil': 48,
#              'British Indian Ocean Territory': 0,
#              'Brunei Darussalam': 0,
#              'Bulgaria': 0,
#              'Burkina Faso': 0,
#              'Burundi': 0,
#              'Cabo Verde': 0,
#              'Cambodia': 2,
#              'Cameroon': 5,
#              'Canada': 19,
#              'Cayman Islands': 0,
#              'Central African Republic': 0,
#              'Chad': 2,
#              'Chile': 14,
#              'China': 365,
#              'Christmas Island': 0,
#              'Cocos (Keeling) Islands': 0,
#              'Colombia': 18,
#              'Comoros': 0,
#              'Congo': 17,
#              'Congo, The Democratic Republic of the': 0,
#              'Cook Islands': 0,
#              'Costa Rica': 0,
#              'Croatia': 0,
#              'Cuba': 23,
#              'Curaçao': 0,
#              'Cyprus': 4,
#              'Czechia': 0,
#              "Côte d'Ivoire": 0,
#              'Denmark': 3,
#              'Djibouti': 0,
#              'Dominica': 0,
#              'Dominican Republic': 0,
#              'Ecuador': 11,
#              'Egypt': 60,
#              'El Salvador': 0,
#              'Equatorial Guinea': 0,
#              'Eritrea': 0,
#              'Estonia': 1,
#              'Ethiopia': 8,
#              'Falkland Islands (Malvinas)': 0,
#              'Faroe Islands': 0,
#              'Fiji': 0,
#              'Finland': 2,
#              'France': 43,
#              'French Guiana': 0,
#              'French Polynesia': 0,
#              'French Southern Territories': 0,
#              'Gabon': 1,
#              'Gambia': 0,
#              'Georgia': 11,
#              'Germany': 69,
#              'Ghana': 3,
#              'Gibraltar': 0,
#              'Greece': 22,
#              'Greenland': 2,
#              'Grenada': 0,
#              'Guadeloupe': 0,
#              'Guam': 1,
#              'Guatemala': 3,
#              'Guernsey': 0,
#              'Guinea': 5,
#              'Guinea-Bissau': 0,
#              'Guyana': 1,
#              'Haiti': 243,
#              'Heard Island and McDonald Islands': 0,
#              'Holy See (Vatican City State)': 0,
#              'Honduras': 52,
#              'Hong Kong': 0,
#              'Hungary': 2,
#              'Iceland': 8,
#              'India': 136,
#              'Indonesia': 51,
#              'Iran, Islamic Republic of': 0,
#              'Iraq': 197,
#              'Ireland': 108,
#              'Isle of Man': 0,
#              'Israel': 538,
#              'Italy': 15,
#              'Jamaica': 4,
#              'Japan': 38,
#              'Jersey': 10,
#              'Jordan': 27,
#              'Kazakhstan': 3,
#              'Kenya': 21,
#              'Kiribati': 0,
#              "Korea, Democratic People's Republic of": 0,
#              'Korea, Republic of': 0,
#              'Kuwait': 5,
#              'Kyrgyzstan': 7,
#              "Lao People's Democratic Republic": 0,
#              'Latvia': 2,
#              'Lebanon': 7,
#              'Lesotho': 1,
#              'Liberia': 7,
#              'Libya': 174,
#              'Liechtenstein': 0,
#              'Lithuania': 9,
#              'Luxembourg': 3,
#              'Macao': 0,
#              'Macedonia, Republic of': 0,
#              'Madagascar': 2,
#              'Malawi': 1,
#              'Malaysia': 4,
#              'Maldives': 2,
#              'Mali': 0,
#              'Malta': 1,
#              'Marshall Islands': 0,
#              'Martinique': 0,
#              'Mauritania': 0,
#              'Mauritius': 0,
#              'Mayotte': 0,
#              'Mexico': 68,
#              'Micronesia, Federated States of': 0,
#              'Moldova, Republic of': 0,
#              'Monaco': 1,
#              'Mongolia': 2,
#              'Montenegro': 0,
#              'Montserrat': 0,
#              'Morocco': 34,
#              'Mozambique': 0,
#              'Myanmar': 3,
#              'Namibia': 0,
#              'Nauru': 1,
#              'Nepal': 1,
#              'Netherlands': 11,
#              'New Caledonia': 0,
#              'New Zealand': 0,
#              'Nicaragua': 1,
#              'Niger': 1,
#              'Nigeria': 8,
#              'Niue': 0,
#              'Norfolk Island': 0,
#              'Northern Mariana Islands': 0,
#              'Norway': 15,
#              'Oman': 1,
#              'Pakistan': 221,
#              'Palau': 70,
#              'Palestine, State of': 0,
#              'Panama': 4,
#              'Papua New Guinea': 0,
#              'Paraguay': 1,
#              'Peru': 5,
#              'Philippines': 5,
#              'Pitcairn': 0,
#              'Poland': 26,
#              'Portugal': 6,
#              'Puerto Rico': 0,
#              'Qatar': 19,
#              'Romania': 7,
#              'Russian Federation': 0,
#              'Rwanda': 7,
#              'Réunion': 0,
#              'Saint Barthélemy': 0,
#              'Saint Helena, Ascension and Tristan da Cunha': 0,
#              'Saint Kitts and Nevis': 0,
#              'Saint Lucia': 0,
#              'Saint Martin (French part)': 0,
#              'Saint Pierre and Miquelon': 0,
#              'Saint Vincent and the Grenadines': 0,
#              'Samoa': 1,
#              'San Marino': 0,
#              'Sao Tome and Principe': 0,
#              'Saudi Arabia': 0,
#              'Senegal': 1,
#              'Serbia': 1,
#              'Seychelles': 0,
#              'Sierra Leone': 0,
#              'Singapore': 31,
#              'Sint Maarten (Dutch part)': 0,
#              'Slovakia': 1,
#              'Slovenia': 2,
#              'Solomon Islands': 0,
#              'Somalia': 6,
#              'South Africa': 0,
#              'South Georgia and the South Sandwich Islands': 0,
#              'South Sudan': 0,
#              'Spain': 19,
#              'Sri Lanka': 0,
#              'Sudan': 40,
#              'Suriname': 1,
#              'Svalbard and Jan Mayen': 0,
#              'Swaziland': 0,
#              'Sweden': 5,
#              'Switzerland': 5,
#              'Syrian Arab Republic': 0,
#              'Taiwan, Province of China': 0,
#              'Tajikistan': 1,
#              'Tanzania, United Republic of': 0,
#              'Thailand': 2,
#              'Timor-Leste': 0,
#              'Togo': 0,
#              'Tokelau': 0,
#              'Tonga': 0,
#              'Trinidad and Tobago': 0,
#              'Tunisia': 21,
#              'Turkey': 53,
#              'Turkmenistan': 1,
#              'Turks and Caicos Islands': 0,
#              'Tuvalu': 0,
#              'Uganda': 6,
#              'Ukraine': 11,
#              'United Arab Emirates': 0,
#              'United Kingdom': 0,
#              'United States': 0,
#              'United States Minor Outlying Islands': 0,
#              'Uruguay': 8,
#              'Uzbekistan': 5,
#              'Vanuatu': 0,
#              'Venezuela, Bolivarian Republic of': 0,
#              'Viet Nam': 0,
#              'Virgin Islands, British': 0,
#              'Virgin Islands, U.S.': 0,
#              'Wallis and Futuna': 0,
#              'Western Sahara': 0,
#              'Yemen': 18,
#              'Zambia': 4,
#              'Zimbabwe': 1,
#              'Åland Islands': 0})
